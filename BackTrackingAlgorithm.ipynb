# %% [markdown]
# <a href="https://colab.research.google.com/github/HussainPythonista/AirBnb/blob/master/BackTrackingAlgorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **BackTracking Algorithm**

# %% [markdown]
# The BackTracking Algorihm which is used to solve combinaion and permutation Problems and the BackTracking Algorithm is Only Perform the **Brute Force Approach** because we Need to check and perform all Possiblities

# %% [markdown]
# **Example**
#
#    If I Have 3 Student and Three Chairs
#    How Arrange Them i that chairs the Possiblities are
#
#    1,B1,B2,B3
#
#    2,B1,B3,B2
#
#    3,B2,B1,B3
#
#    4,B2,B3,B1
#
#    5,B3,B1,B2
#
#    6,B3,B2,B1
#
#    3 Factorial![Drawing.jpeg](data:image/jpeg;base64,...)
#
#    Total 6Possiblities ,
#
#    The Backtracking is using for finding this Possiblities

# %% [markdown]
# **We can apply some Conditon in recursion tree that one stops recursion move Further**
#
# That Function is Called **Bounding Function**

# %% [markdown]
# Example:
#
#   The Boy3 should not sit in the middle
#
#   The Posiblties are
#
#   B1,B2,B3
#
#   B2,B1,B3
#
#   B3,B1,B2
#
#   Three Posiblites
#
#   This one is called constraints,if the recursion hits the condition kill the recursion
